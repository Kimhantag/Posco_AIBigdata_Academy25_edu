# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\gksxk\anaconda3\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\gksxk\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\gksxk\anaconda3\lib\site-packages (from mlxtend) (2.1.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\gksxk\anaconda3\lib\site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\gksxk\anaconda3\lib\site-packages (from mlxtend) (3.8.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\gksxk\anaconda3\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gksxk\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gksxk\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gksxk\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gksxk\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\gksxk\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 445.2 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.4 MB 751.6 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.4 MB 1.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.4/1.4 MB 1.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 2.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 2.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 2.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1

# %%
# !pip install apriori
# Out:
# Collecting apriori
#   Downloading apriori-1.0.0.tar.gz (1.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: apriori
#   Building wheel for apriori (setup.py): started
#   Building wheel for apriori (setup.py): finished with status 'done'
#   Created wheel for apriori: filename=apriori-1.0.0-py3-none-any.whl size=2461 sha256=1a850e84109ab12c11482b1480f2f428d262d3b015e6af66af0475d258d2a22f
#   Stored in directory: c:\users\gksxk\appdata\local\pip\cache\wheels\5c\7e\9b\efc2bca640ccdfdf93f9031deac196dbf19e25a5526bc65021
# Successfully built apriori
# Installing collected packages: apriori
# Successfully installed apriori-1.0.0

# %% [markdown]
# #### 패키지 불러오기

# %%
# 데이터 구성:Series, DataFrame
import pandas as pd
# 행렬 연산
import numpy as np
# 데이터 전처리 : 항목 값에 대한 index 생성
from mlxtend.preprocessing import TransactionEncoder
# 지지도 계산
from mlxtend.frequent_patterns import apriori
# 연관 규칙
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# #### 데이터 구성하기

# %%
df_raw = pd.read_csv("Big Data 분석/상품구매.csv")
# df_raw = pd.read_csv("D:/WORK/DATA/상품구매.csv", engine = "python")
df_raw.head(10)
# Out:
#      ID      PRODUCT
# 0  C-11     BAGUETTE
# 1  C-11      HERRING
# 2  C-11      AVOCADO
# 3  C-11    ARTICHOKE
# 4  C-11     HEINEKEN
# 5  C-11       APPLES
# 6  C-11  CORNED BEEF
# 7  C-12      HERRING
# 8  C-12  CORNED BEEF
# 9  C-12       APPLES

# %% [markdown]
# #### 데이터 구성-전처리

# %%
# 고객 ID 리스트 행성 및 정렬
ID = list(set(df_raw["ID"]))
ID.sort()

# 고객ID별 상품 매칭
list_association = []
for i in ID:
    # ID별 구매 데이터 추출
    tmp_list = list(df_raw[df_raw["ID"] == i]["PRODUCT"])
    tmp_list.sort()
    # ID별 구매 데이터를 리스트에 담기
    list_association.append(tmp_list)

# 리스트 출력
for row in list_association:
    print(row)
# Out:
# ['APPLES', 'ARTICHOKE', 'AVOCADO', 'BAGUETTE', 'CORNED BEEF', 'HEINEKEN', 'HERRING']
# ['APPLES', 'CORNED BEEF', 'HEINEKEN', 'HERRING', 'OLIVES', 'SARDINES', 'STEAK']
# ['APPLES', 'AVOCADO', 'BAGUETTE', 'ICE CREAM', 'PEPPERS', 'SARDINES', 'STEAK']
# ['APPLES', 'COKE', 'CORNED BEEF', 'HAM', 'HERRING', 'OLIVES', 'TURKEY']
# ['ARTICHOKE', 'BOURBON', 'COKE', 'HAM', 'ICE CREAM', 'OLIVES', 'TURKEY']
# ['ARTICHOKE', 'AVOCADO', 'BAGUETTE', 'COKE', 'HEINEKEN', 'HERRING', 'TURKEY']
# ['APPLES', 'CHICKEN', 'COKE', 'CORNED BEEF', 'HEINEKEN', 'ICE CREAM', 'SARDINES']
# ['BAGUETTE', 'BOURBON', 'CRACKERS', 'HEINEKEN', 'OLIVES', 'PEPPERS', 'SODA']
# ['BOURBON', 'CRACKERS', 'HEINEKEN', 'HERRING', 'OLIVES', 'SODA', 'STEAK']
# ['APPLES', 'BAGUETTE', 'CORNED BEEF', 'HAM', 'HERRING', 'OLIVES', 'TURKEY']
# ['ARTICHOKE', 'AVOCADO', 'BAGUETTE', 'BOURBON', 'CORNED BEEF', 'HEINEKEN', 'HERRING']
# ['ARTICHOKE', 'BOURBON', 'CRACKERS', 'HEINEKEN', 'OLIVES', 'SODA', 'STEAK']
# ['BOURBON', 'CORNED BEEF', 'CRACKERS', 'HEINEKEN', 'HERRING', 'OLIVES', 'SODA']
# ['APPLES', 'BAGUETTE', 'CHICKEN', 'COKE', 'HEINEKEN', 'ICE CREAM', 'SARDINES']
# ['CHICKEN', 'COKE', 'CORNED BEEF', 'HEINEKEN', 'ICE CREAM', 'PEPPERS', 'SARDINES']
# ['APPLES', 'BAGUETTE', 'BOURBON', 'COKE', 'ICE CREAM', 'OLIVES', 'TURKEY']
# ['AVOCADO', 'BOURBON', 'COKE', 'ICE CREAM', 'OLIVES', 'SODA', 'TURKEY']
# ['ARTICHOKE', 'BOURBON', 'CRACKERS', 'HEINEKEN', 'OLIVES', 'PEPPERS', 'SODA']
# ['BOURBON', 'COKE', 'ICE CREAM', 'OLIVES', 'SARDINES', 'SODA', 'TURKEY']
# ['BOURBON', 'COKE', 'HAM', 'ICE CREAM', 'OLIVES', 'SODA', 'TURKEY']

# %%
# Items 기준으로 포함 여부에 따라 True/False 로 변환
enc = TransactionEncoder()
df_raw_enc = enc.fit_transform(X = list_association)

# 함수 fit_transform 는 데이터를 행렬의 형태로 반환, pandas의 DataFrame의 형태로 변환
df_asso = pd.DataFrame(df_raw_enc, columns = enc.columns_)

df_asso.head()
# Out:
#    APPLES  ARTICHOKE  AVOCADO  BAGUETTE  BOURBON  CHICKEN   COKE  CORNED BEEF  \
# 0    True       True     True      True    False    False  False         True
# 1    True      False    False     False    False    False  False         True
# 2    True      False     True      True    False    False  False        False
# 3    True      False    False     False    False    False   True         True
# 4   False       True    False     False     True    False   True        False
#
#    CRACKERS    HAM  HEINEKEN  HERRING  ICE CREAM  OLIVES  PEPPERS  SARDINES  \
# 0     False  False      True     True      False   False    False     False
# 1     False  False      True     True      False    True    False      True
# 2     False  False     False    False       True   False     True      True
# 3     False   True     False     True      False    True    False     False
# 4     False   True     False    False       True    True    False     False
#
#     SODA  STEAK  TURKEY
# 0  False  False   False
# 1  False   True   False
# 2  False   True   False
# 3  False  False    True
# 4  False  False    True

# %% [markdown]
# #### 연관규칙 생성

# %%
# 규칙 선택 최소 지지
v_min_support = 0.4

# 연관규칙 생성 및 지지도 임계값 적용
# df_freq = apriori(df_asso, min_support = 0.4, use_colnames = True)  # 직접 입력 
df_freq = apriori(df_asso, min_support = v_min_support, use_colnames = True) # 매개값 사용

# itemsets 항목 확인
df_freq.round(3) 
# df_freq[9:16].round(3) # 부분 확인
# Out:
#     support                 itemsets
# 0      0.40                 (APPLES)
# 1      0.40               (BAGUETTE)
# 2      0.55                (BOURBON)
# 3      0.50                   (COKE)
# 4      0.40            (CORNED BEEF)
# 5      0.60               (HEINEKEN)
# 6      0.40                (HERRING)
# 7      0.45              (ICE CREAM)
# 8      0.65                 (OLIVES)
# 9      0.40                   (SODA)
# 10     0.40                 (TURKEY)
# 11     0.50        (BOURBON, OLIVES)
# 12     0.40          (BOURBON, SODA)
# 13     0.40        (COKE, ICE CREAM)
# 14     0.40           (SODA, OLIVES)
# 15     0.40  (BOURBON, SODA, OLIVES)

# %% [markdown]
# #### 연관규칙 선택

# %%
#향상도 기준 : lift
df_asso_rule = association_rules(df_freq, metric="lift" ,min_threshold = 1.3)
df_asso_rule.round(3)
# Out:
#           antecedents        consequents  antecedent support  \
# 0           (BOURBON)           (OLIVES)                0.55
# 1            (OLIVES)          (BOURBON)                0.65
# 2           (BOURBON)             (SODA)                0.55
# 3              (SODA)          (BOURBON)                0.40
# 4              (COKE)        (ICE CREAM)                0.50
# 5         (ICE CREAM)             (COKE)                0.45
# 6              (SODA)           (OLIVES)                0.40
# 7            (OLIVES)             (SODA)                0.65
# 8     (SODA, BOURBON)           (OLIVES)                0.40
# 9   (BOURBON, OLIVES)             (SODA)                0.50
# 10     (SODA, OLIVES)          (BOURBON)                0.40
# 11          (BOURBON)     (SODA, OLIVES)                0.55
# 12             (SODA)  (BOURBON, OLIVES)                0.40
# 13           (OLIVES)    (SODA, BOURBON)                0.65
#
#     consequent support  support  confidence   lift  leverage  conviction  \
# 0                 0.65      0.5       0.909  1.399     0.142        3.85
# 1                 0.55      0.5       0.769  1.399     0.142        1.95
# 2                 0.40      0.4       0.727  1.818     0.180        2.20
# 3                 0.55      0.4       1.000  1.818     0.180         inf
# 4                 0.45      0.4       0.800  1.778     0.175        2.75
# 5                 0.50      0.4       0.889  1.778     0.175        4.50
# 6                 0.65      0.4       1.000  1.538     0.140         inf
# 7                 0.40      0.4       0.615  1.538     0.140        1.56
# 8                 0.65      0.4       1.000  1.538     0.140         inf
# 9                 0.40      0.4       0.800  2.000     0.200        3.00
# 10                0.55      0.4       1.000  1.818     0.180         inf
# 11                0.40      0.4       0.727  1.818     0.180        2.20
# 12                0.50      0.4       1.000  2.000     0.200         inf
# 13                0.40      0.4       0.615  1.538     0.140        1.56
#
#     zhangs_metric
# 0           0.633
# 1           0.814
# 2           1.000
# 3           0.750
# 4           0.875
# 5           0.795
# 6           0.583
# 7           1.000
# 8           0.583
# 9           1.000
# 10          0.750
# 11          1.000
# 12          0.833
# 13          1.000

# %%
#신뢰도 기준:confidence
df_asso_rule = association_rules(df_freq, metric="confidence" ,min_threshold = 0.7)
df_asso_rule.round(3)
# Out:
#           antecedents        consequents  antecedent support  \
# 0           (BOURBON)           (OLIVES)                0.55
# 1            (OLIVES)          (BOURBON)                0.65
# 2           (BOURBON)             (SODA)                0.55
# 3              (SODA)          (BOURBON)                0.40
# 4              (COKE)        (ICE CREAM)                0.50
# 5         (ICE CREAM)             (COKE)                0.45
# 6              (SODA)           (OLIVES)                0.40
# 7     (SODA, BOURBON)           (OLIVES)                0.40
# 8   (BOURBON, OLIVES)             (SODA)                0.50
# 9      (SODA, OLIVES)          (BOURBON)                0.40
# 10          (BOURBON)     (SODA, OLIVES)                0.55
# 11             (SODA)  (BOURBON, OLIVES)                0.40
#
#     consequent support  support  confidence   lift  leverage  conviction  \
# 0                 0.65      0.5       0.909  1.399     0.142        3.85
# 1                 0.55      0.5       0.769  1.399     0.142        1.95
# 2                 0.40      0.4       0.727  1.818     0.180        2.20
# 3                 0.55      0.4       1.000  1.818     0.180         inf
# 4                 0.45      0.4       0.800  1.778     0.175        2.75
# 5                 0.50      0.4       0.889  1.778     0.175        4.50
# 6                 0.65      0.4       1.000  1.538     0.140         inf
# 7                 0.65      0.4       1.000  1.538     0.140         inf
# 8                 0.40      0.4       0.800  2.000     0.200        3.00
# 9                 0.55      0.4       1.000  1.818     0.180         inf
# 10                0.40      0.4       0.727  1.818     0.180        2.20
# 11                0.50      0.4       1.000  2.000     0.200         inf
#
#     zhangs_metric
# 0           0.633
# 1           0.814
# 2           1.000
# 3           0.750
# 4           0.875
# 5           0.795
# 6           0.583
# 7           0.583
# 8           1.000
# 9           0.750
# 10          1.000
# 11          0.833
